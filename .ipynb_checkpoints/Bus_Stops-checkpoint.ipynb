# %% [markdown]
# # Bus Stops optimisation in Paris

# %% [markdown]
# Aiming at finding optimal bus stops for the city of Paris in regard to the RATP stations stops
#
# RATP stations data : https://dataratp.opendatasoft.com/explore/dataset/positions-geographiques-des-stations-du-reseau-ratp/

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import osmnx as ox
import networkx as nx
import geopandas

# %% [markdown]
# ## Datasets

# %%
# Paris streets graph
G = ox.graph_from_place('Paris, France', network_type='drive')

# %%
fig, ax = ox.plot_graph(G)

# %% [markdown]
# getting the nodes

# %%
paris_gdf , _= ox.graph_to_gdfs(G)
paris_gdf
# Out:
#                     y         x       osmid          highway  ref  \
# 5509971973  48.865456  2.391081  5509971973              NaN  NaN
# 166297606   48.816421  2.360142   166297606              NaN  NaN
# 271450120   48.875688  2.277891   271450120              NaN  NaN
# 116129800   48.844563  2.287032   116129800              NaN  NaN
# 116129802   48.843989  2.288553   116129802              NaN  NaN
# ...               ...       ...         ...              ...  ...
# 94142447    48.876005  2.368349    94142447  traffic_signals  NaN
# 21659631    48.838379  2.353684    21659631              NaN  NaN
# 21659629    48.837835  2.352156    21659629              NaN  NaN
# 299270133   48.879638  2.340674   299270133              NaN  NaN
# 299270134   48.879758  2.340175   299270134              NaN  NaN
#
#                             geometry
# 5509971973  POINT (2.39108 48.86546)
# 166297606   POINT (2.36014 48.81642)
# 271450120   POINT (2.27789 48.87569)
# 116129800   POINT (2.28703 48.84456)
# 116129802   POINT (2.28855 48.84399)
# ...                              ...
# 94142447    POINT (2.36835 48.87600)
# 21659631    POINT (2.35368 48.83838)
# 21659629    POINT (2.35216 48.83783)
# 299270133   POINT (2.34067 48.87964)
# 299270134   POINT (2.34017 48.87976)
#
# [10066 rows x 6 columns]

# %%
# RATP stations dataframe
ratp_stations_df = pd.read_csv('Data/positions-geographiques-des-stations-du-reseau-ratp.csv', sep=';')
ratp_stations_df.head()
# Out:
#         ID               Name                            Description  \
# 0  3677677    RUE DE LA FERME  ROND-POINT MARTIN LUTHER KING - 77258
# 1  3677688  COLLEGE LE LUZARD               COURS DES ROCHES - 77337
# 2  3678812     ZONE TECHNIQUE        ROUTE DES ANNIVERSAIRES - 95527
# 3  3678816     ENTRETIEN NORD           ROUTE DE L'ARPENTEUR - 95527
# 4  3682876              AVRON   63 BOULEVARD ALSACE-LORRAINE - 94058
#
#                    Coordinates
# 0  48.8359484574,2.62990289517
# 1     48.8467902961,2.61369101
# 2   49.0119496186,2.5332905562
# 3  49.0114652199,2.51552950645
# 4  48.8500655011,2.49939528589

# %%
ratp_stations_df.dtypes
# Out:
# ID              int64
# Name           object
# Description    object
# Coordinates    object
# dtype: object

# %% [markdown]
# Let's keep only stations in Paris

# %%
ratp_stations_Paris = ratp_stations_df['Description'].apply(lambda x : True if '- 75' in x else False)
ratp_stations_Paris.sum()
# Out:
# 6116

# %%
ratp_stations_Paris_df = ratp_stations_df.loc[ratp_stations_Paris,:]

# %%
ratp_stations_Paris_df.head()
# Out:
#          ID                               Name  \
# 16  3685734               CHATEAU DE VINCENNES
# 35  7275123                   GERARD DE NERVAL
# 36  7275132                            SIMPLON
# 37  7275139  MAGENTA - MAUBEUGE - GARE DU NORD
# 38  7275143                      GARE DE L'EST
#
#                                  Description                  Coordinates
# 16               PISTE GARE ROUTIERE - 75112  48.8442170813,2.44079723454
# 35  AVENUE DE LA PORTE DE MONTMARTRE - 75118  48.9007204012,2.33519629626
# 36               46 BOULEVARD ORNANO - 75118  48.8948064764,2.34715016514
# 37      140-142 BOULEVARD DE MAGENTA - 75110  48.8813341943,2.35171250385
# 38        74 BOULEVARD DE STRASBOURG - 75110  48.8755903947,2.35801931852

# %% [markdown]
# Now, let's transform coordinates in geometry type

# %%
ratp_stations_Paris_df['x']=ratp_stations_Paris_df['Coordinates'].apply(lambda x : float(x.split(',')[1]))
ratp_stations_Paris_df['y']=ratp_stations_Paris_df['Coordinates'].apply(lambda x : float(x.split(',')[0]))
ratp_stations_Paris_df.head()
# Out:
# D:\Miniconda3\envs\ox\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# D:\Miniconda3\envs\ox\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          ID                               Name  \
# 16  3685734               CHATEAU DE VINCENNES
# 35  7275123                   GERARD DE NERVAL
# 36  7275132                            SIMPLON
# 37  7275139  MAGENTA - MAUBEUGE - GARE DU NORD
# 38  7275143                      GARE DE L'EST
#
#                                  Description                  Coordinates  \
# 16               PISTE GARE ROUTIERE - 75112  48.8442170813,2.44079723454
# 35  AVENUE DE LA PORTE DE MONTMARTRE - 75118  48.9007204012,2.33519629626
# 36               46 BOULEVARD ORNANO - 75118  48.8948064764,2.34715016514
# 37      140-142 BOULEVARD DE MAGENTA - 75110  48.8813341943,2.35171250385
# 38        74 BOULEVARD DE STRASBOURG - 75110  48.8755903947,2.35801931852
#
#            x          y
# 16  2.440797  48.844217
# 35  2.335196  48.900720
# 36  2.347150  48.894806
# 37  2.351713  48.881334
# 38  2.358019  48.875590

# %%
ratp_stations_Paris_gdf = geopandas.GeoDataFrame(ratp_stations_Paris_df,
                             geometry=geopandas.points_from_xy(ratp_stations_Paris_df.x, ratp_stations_Paris_df.y))
ratp_stations_Paris_gdf.head()
# Out:
#          ID                               Name  \
# 16  3685734               CHATEAU DE VINCENNES
# 35  7275123                   GERARD DE NERVAL
# 36  7275132                            SIMPLON
# 37  7275139  MAGENTA - MAUBEUGE - GARE DU NORD
# 38  7275143                      GARE DE L'EST
#
#                                  Description                  Coordinates  \
# 16               PISTE GARE ROUTIERE - 75112  48.8442170813,2.44079723454
# 35  AVENUE DE LA PORTE DE MONTMARTRE - 75118  48.9007204012,2.33519629626
# 36               46 BOULEVARD ORNANO - 75118  48.8948064764,2.34715016514
# 37      140-142 BOULEVARD DE MAGENTA - 75110  48.8813341943,2.35171250385
# 38        74 BOULEVARD DE STRASBOURG - 75110  48.8755903947,2.35801931852
#
#            x          y                  geometry
# 16  2.440797  48.844217  POINT (2.44080 48.84422)
# 35  2.335196  48.900720  POINT (2.33520 48.90072)
# 36  2.347150  48.894806  POINT (2.34715 48.89481)
# 37  2.351713  48.881334  POINT (2.35171 48.88133)
# 38  2.358019  48.875590  POINT (2.35802 48.87559)

# %%
ratp_stations_Paris_gdf['geometry'].plot(ax=ax, markersize=20, color='green')
fig

# %% [markdown]
# Let's delete nodes out of Paris we missed out

# %%
#To be done

# %% [markdown]
# We can now combine the nodes into one graph

# %%
G_new = G.copy()
nx.set_node_attributes(G_new, pd.Series('blue', index=paris_gdf.index), 'color')

# %%
G_new.add_nodes_from(ratp_stations_Paris_gdf.index,ratp=True, color='green')

# %%
nx.set_node_attributes(G_new, pd.Series(ratp_stations_Paris_gdf.x, index=ratp_stations_Paris_gdf.index).to_dict(), 'x')
nx.set_node_attributes(G_new, pd.Series(ratp_stations_Paris_gdf.y, index=ratp_stations_Paris_gdf.index).to_dict(), 'y')

# %%
paris_gdf2 , _= ox.graph_to_gdfs(G_new)
paris_gdf2
# Out:
#                     y         x         osmid  color highway  ref  ratp  \
# 5509971973  48.865456  2.391081  5.509972e+09   blue     NaN  NaN   NaN
# 166297606   48.816421  2.360142  1.662976e+08   blue     NaN  NaN   NaN
# 271450120   48.875688  2.277891  2.714501e+08   blue     NaN  NaN   NaN
# 116129800   48.844563  2.287032  1.161298e+08   blue     NaN  NaN   NaN
# 116129802   48.843989  2.288553  1.161298e+08   blue     NaN  NaN   NaN
# ...               ...       ...           ...    ...     ...  ...   ...
# 25313       48.852162  2.339706           NaN  green     NaN  NaN  True
# 25315       48.835565  2.397499           NaN  green     NaN  NaN  True
# 25316       48.861378  2.302112           NaN  green     NaN  NaN  True
# 25318       48.819714  2.364081           NaN  green     NaN  NaN  True
# 25331       48.840029  2.346364           NaN  green     NaN  NaN  True
#
#                             geometry
# 5509971973  POINT (2.39108 48.86546)
# 166297606   POINT (2.36014 48.81642)
# 271450120   POINT (2.27789 48.87569)
# 116129800   POINT (2.28703 48.84456)
# 116129802   POINT (2.28855 48.84399)
# ...                              ...
# 25313       POINT (2.33971 48.85216)
# 25315       POINT (2.39750 48.83556)
# 25316       POINT (2.30211 48.86138)
# 25318       POINT (2.36408 48.81971)
# 25331       POINT (2.34636 48.84003)
#
# [16182 rows x 8 columns]

# %%
# verify we have the good amount of nodes
16182-10066
# Out:
# 6116

# %% [markdown]
# All nodes are now in the same graph !

# %%
ox.plot_graph(G_new, node_color=paris_gdf2.color)
# Out:
# (<Figure size 952.984x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2d21ae419e8>)

# %% [markdown]
# ### Best nodes for a bus stop

# %% [markdown]
# Let's find the nodes with the most ratp nodes in a 200 meters range

# %%
## need to project the node to use meters instead of longitude and latitude
projected_point, projection_crs = ox.project_geometry(ratp_stations_Paris_gdf['geometry'].iloc[0])
projected_buffer = projected_point.buffer(200)
buffer, latlong_crs = ox.project_geometry(projected_buffer, crs=projection_crs, to_latlong=True)
buffer

# %%
#Find the number of ratp stations in the circle around the node
def intersect(node, radius=200):
    projected_node, projection_crs = ox.project_geometry(node)
    projected_zone = projected_node.buffer(radius)
    zone, _ = ox.project_geometry(projected_zone, crs=projection_crs, to_latlong=True)
    number = ratp_stations_Paris_gdf.intersects(zone)
    return number.sum()

# %%
paris_gdf['Close_ratp_stations'] = paris_gdf['geometry'].apply(lambda x : intersect(x, radius=200))

# %%
paris_gdf.sort_values('Close_ratp_stations', ascending=False)
# Out:
#                    y         x      osmid          highway  ref  \
# 178764471  48.874829  2.326771  178764471              NaN  NaN
# 169320949  48.874182  2.326925  169320949  traffic_signals  NaN
# 676821350  48.857239  2.347120  676821350              NaN  NaN
# 676890491  48.857291  2.346919  676890491              NaN  NaN
# 169320939  48.874163  2.325795  169320939  traffic_signals  NaN
# ...              ...       ...        ...              ...  ...
# 357495388  48.863449  2.249831  357495388              NaN  NaN
# 267104800  48.847262  2.416004  267104800              NaN  NaN
# 180269744  48.836542  2.267588  180269744              NaN  NaN
# 60912208   48.870554  2.388225   60912208              NaN  NaN
# 904150573  48.867159  2.405020  904150573              NaN  NaN
#
#                            geometry  Close_ratp_stations
# 178764471  POINT (2.32677 48.87483)                   91
# 169320949  POINT (2.32692 48.87418)                   89
# 676821350  POINT (2.34712 48.85724)                   87
# 676890491  POINT (2.34692 48.85729)                   87
# 169320939  POINT (2.32579 48.87416)                   87
# ...                             ...                  ...
# 357495388  POINT (2.24983 48.86345)                    0
# 267104800  POINT (2.41600 48.84726)                    0
# 180269744  POINT (2.26759 48.83654)                    0
# 60912208   POINT (2.38822 48.87055)                    0
# 904150573  POINT (2.40502 48.86716)                    0
#
# [10066 rows x 7 columns]

# %%
G_final = G.copy()

# %%
nx.set_node_attributes(G_final, pd.Series('blue', index=paris_gdf.index), 'color')
paris_gdf['color']='blue'

# %% [markdown]
# Let's change the color of nodes with more than 50 ratp stations in a radius of 200m in red

# %%
high_close_ratp_stations = paris_gdf.loc[paris_gdf['Close_ratp_stations']>=50]
high_close_ratp_stations.head()
# Out:
#                    y         x      osmid          highway  ref  \
# 361091     48.874814  2.357383     361091  traffic_signals  NaN
# 361100     48.876362  2.355974     361100  traffic_signals  NaN
# 361102     48.878524  2.354064     361102              NaN  NaN
# 676890491  48.857291  2.346919  676890491              NaN  NaN
# 676890544  48.857892  2.347183  676890544  traffic_signals  NaN
#
#                            geometry  Close_ratp_stations color
# 361091     POINT (2.35738 48.87481)                   63  blue
# 361100     POINT (2.35597 48.87636)                   65  blue
# 361102     POINT (2.35406 48.87852)                   52  blue
# 676890491  POINT (2.34692 48.85729)                   87  blue
# 676890544  POINT (2.34718 48.85789)                   64  blue

# %%
paris_gdf['color'][high_close_ratp_stations.index] = 'red'
# Out:
# D:\Miniconda3\envs\ox\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
nx.set_node_attributes(G_final, pd.Series('red', index=high_close_ratp_stations.index), 'color')

# %%
ox.plot_graph(G_final, node_color=paris_gdf.color)
# Out:
# (<Figure size 952.984x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2d21af35f28>)

# %% [markdown]
# 5 or 6 main places seem to have good transport links and might be suitable place for bus stops !

# %% [markdown]
# However, until now only the number of stations around a node was taken into account and not the amount of possible clients the transports could bring. Let's check if we could have this information

# %% [markdown]
# ## Using the traffic for each ratp station

# %% [markdown]
# The traffic in every ratp station has to be taken into account to find more accurately the best nodes !

# %%
# To be done
